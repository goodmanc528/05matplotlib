# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (40 * np.random.rand(N))**2  # 0 to 15 point radii

fig, ax = plt.subplots()


plt.scatter(x, y, s=area, c=['gold', 'lightskyblue','lightcoral'], alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
